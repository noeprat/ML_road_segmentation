# %%
data_augm, gt_augm = preprocessing(cut_format=True)
# Do cross validation on the data
data_folds, gt_folds = cross_validation(data_augm, gt_augm, 5)
data_folds = np.array(data_folds)
gt_folds = np.array(gt_folds)
data_folds.shape
